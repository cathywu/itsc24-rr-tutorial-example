# %%
import os
import sys
from pathlib import Path

# Be careful to only change to the parent directory once, even if this cell is executed multiple times
try:
    CHANGED_ROOT
except NameError:
    parent_dir = Path(os.getcwd()).parents[0]
    sys.path.append(f'{parent_dir}/example')

import environment

# Change working directory to the project root
# to use the same relative paths used in example/...
# %cd $parent_dir
CHANGED_ROOT = True

# %matplotlib inline

# %%
environment.Environment.plot_fundamental_diagrams()
